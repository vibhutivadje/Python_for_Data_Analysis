# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/vibhutivadje/Documents/Git_Repos/Datasets/Neighbor_Data.csv')
df.head(5)
# Out:
#    user_id user_created_timestamp             user_conversion_dma  \
# 0   579583                21:31.8  unknown (no conversion events)
# 1    93798                03:46.5                         Chicago
# 2   643207                56:36.5                      Fort Wayne
# 3   215070                04:39.1  unknown (no conversion events)
# 4   405131                46:30.3                       Las Vegas
#
#   user_use_case_type user_account_type user_attribution_source  \
# 0             renter       residential                    Paid
# 1               host       residential                    Paid
# 2               host       residential                    Paid
# 3             renter       residential                    Paid
# 4               host       residential                  Direct
#
#   user_attribution_channel                        user_device_id  \
# 0                   Google                                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       10000 non-null  int64
#  1   user_created_timestamp                        10000 non-null  object
#  2   user_conversion_dma                           10000 non-null  object
#  3   user_use_case_type                            9632 non-null   object
#  4   user_account_type                             10000 non-null  object
#  5   user_attribution_source                       10000 non-null  object
#  6   user_attribution_channel                      6466 non-null   object
#  7   user_device_id                                2677 non-null   object
#  8   host_published_listing_count                  10000 non-null  int64
# ...

# %%
print(df.shape)
# Out:
# (10000, 25)

# %%
total_cells = np.product(df.shape)
total_cells
# Out:
# 250000

# %%
#Calculate the percentage of missing values in each column
missing_values = df.isnull().mean()*100
missing_values.sort_values(ascending=False)
# Out:
# host_first_paid_successful_timestamp            97.70
# host_average_published_listing_quality_score    95.98
# renter_first_paid_successful_timestamp          93.11
# host_first_listing_published_timestamp          84.81
# user_device_id                                  73.23
# host_average_listing_quality_score              58.21
# host_current_published_listing_count            58.21
# host_occupancy_type                             58.21
# user_attribution_channel                        35.34
# user_use_case_type                               3.68
# is_potential_power_host                          0.00
# delinquent_renter                                0.00
# conversations_as_renter_count                    0.00
# conversations_as_host_count                      0.00
# renter_successful_reservation_count              0.00
# renter_reservation_count                         0.00
# user_id                                          0.00
# ...

# %% [markdown]
# The dataset has a significant amount of missing data in several columns. Here's a summary of the columns with missing values, sorted by the percentage of data missing:
#
# <li>host_first_paid_successful_timestamp: 97.7% missing</li>
# <li>host_average_published_listing_quality_score: 95.98% missing</li>
# <li>renter_first_paid_successful_timestamp: 93.11% missing</li>
# <li>host_first_listing_published_timestamp: 84.81% missing</li>
# <li>user_device_id: 73.23% missing</li>
#
# host_average_listing_quality_score, host_current_published_listing_count, host_occupancy_type: 58.21% missing each
# user_attribution_channel: 35.34% missing
# user_use_case_type: 3.68% missing
# Columns with such high percentages of missing values may be less useful for some types of analysis unless we can impute the missing data or unless the presence of data itself is indicative of some behavior or characteristic.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Select numerical columns (excluding user_id as it's just an identifier)
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.drop('user_id')

# Plot histograms for numerical columns
plt.figure(figsize=(15, 15))

for i, col in enumerate(numerical_cols, 1):
    plt.subplot(5, 3, i)  # We're expecting 15 numerical columns based on the description
    sns.histplot(df[col].dropna(), kde=False)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here are the histograms for the numerical columns:
#
# Most of the histograms are heavily skewed toward the lower end, indicating that the majority of the counts are low (close to zero) for several of the numerical variables.
# A few variables, like host_published_listing_count, renter_reservation_count, and conversations_as_host_count, have long tails, which suggests the presence of outliers or a few users with very high activity.
# Now, let's move on to the correlation analysis. Correlations can reveal whether there are any strong linear relationships between pairs of numerical variables. We'll calculate the correlation matrix and visualize it using a heatmap.​

# %%
# Calculate the correlation matrix
corr_matrix = df[numerical_cols].corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The heatmap displays the correlation coefficients between pairs of numerical variables. Here are some key points:
#
# There are several pairs with high correlation coefficients, indicating a strong linear relationship. For example:
#
# renter_reservation_count and renter_successful_reservation_count are highly correlated, which makes sense as successful reservations are a subset of total reservations.
# conversations_as_host_count and host_published_listing_count also show a strong correlation, suggesting that hosts with more listings might engage in more conversations.
# Many coefficients are close to zero, indicating no linear relationship between those pairs of variables.
#
# It's important to remember that correlation does not imply causation, and high correlation between two variables does not necessarily mean that one variable causes the other to change.

# %% [markdown]
# # Cleaning data

# %% [markdown]
# Cleaning the data typically involves several steps tailored to the specific needs of the analysis or modeling. Common data cleaning steps include:
#
# Handling Missing Values:
#
# Dropping columns with a high percentage of missing values if they are not crucial for the analysis.
# Imputing missing values for other columns using statistical methods (mean, median, mode) or more complex algorithms.
# Dropping rows where crucial information is missing.
# Correcting Data Types:
#
# Ensuring that each column is of the correct data type (e.g., converting timestamp strings to datetime objects).
# Removing Duplicates:
#
# Identifying and removing duplicate rows to prevent skewing the analysis.
# Handling Outliers:
#
# Identifying outliers and deciding whether to keep, cap/floor, or transform them.
# Normalizing/Standardizing Data:
#
# Applying normalization or standardization to numerical columns, especially if using methods sensitive to scale (like distance-based algorithms).
# Encoding Categorical Variables:
#
# Converting categorical variables to a format that can be provided to ML models (like one-hot encoding).

# %% [markdown]
# For this dataset, here's what I propose based on the information we have so far:
#
# Drop columns with more than 60% missing values.
# Convert timestamp columns to datetime data type.
# We could impute missing values for columns with less missing data, but we'll need to decide on the method.
# Check for and remove any duplicate rows.
# For outliers, we need to determine whether they are errors or valuable extreme values; this often depends on domain knowledge.
# Let's start with the first two steps and then review our dataset. We'll drop the columns with more than 60% missing values and convert timestamp strings to datetime objects.

# %%
# Drop columns with more than 60% missing values
columns_to_drop = missing_values[missing_values > 60].index
df_cleaned = df.drop(columns=columns_to_drop)

# Convert timestamp columns to datetime objects
timestamp_cols = [col for col in df_cleaned.columns if 'timestamp' in col]
for col in timestamp_cols:
    df_cleaned[col] = pd.to_datetime(df_cleaned[col], errors='coerce')

# Check the data types and missing values after these steps
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               10000 non-null  int64
#  1   user_created_timestamp                3967 non-null   datetime64[ns]
#  2   user_conversion_dma                   10000 non-null  object
#  3   user_use_case_type                    9632 non-null   object
#  4   user_account_type                     10000 non-null  object
#  5   user_attribution_source               10000 non-null  object
#  6   user_attribution_channel              6466 non-null   object
#  7   host_published_listing_count          10000 non-null  int64
#  8   host_current_published_listing_count  4179 non-null   float64
#  9   host_average_listing_quality_score    4179 non-null   float64
# ...

# %% [markdown]
# After cleaning, the dataset now contains 20 columns, down from the original 25. Here are the changes made:
#
# We've dropped the columns with more than 60% missing values.
# We've converted the appropriate columns to datetime data types. It appears there was a discrepancy in the user_created_timestamp column, which resulted in a reduction of non-null entries; this could be due to incorrectly formatted dates. We should investigate this further.
# Next steps include:
#
# Handling missing values in the remaining columns with a significant amount of missing data.
# Removing any duplicate rows if present.
# Assessing and deciding how to handle outliers.
# Before proceeding, would you like to address the issue with user_created_timestamp, handle the other missing values, remove duplicates, or look into potential outliers?​

# %% [markdown]
# # EDA on cleaned data:

# %% [markdown]
# Certainly! Now that we have a cleaner dataset, we can perform a more in-depth Exploratory Data Analysis (EDA). Here's what we'll do:
#
# Examine the Distribution of Categorical Variables:
#
# We'll look at the distribution of the remaining categorical variables to understand the diversity in the dataset.
# Analyze Numerical Variables:
#
# Revisit the histograms of numerical variables with the cleaned data.
# Create box plots to visualize outliers.
# Investigate Timestamps:
#
# Since we noticed an issue with user_created_timestamp, we should examine the valid timestamps to understand the time range we're dealing with.
# Duplicate Rows:
#
# Check for and remove any duplicate entries.
# Multivariate Analysis:
#
# We'll look at how the numerical variables relate to one another and to some of the categorical variables.

# %%
# Categorical columns
categorical_cols = df_cleaned.select_dtypes(include=['object', 'bool']).columns

# Plot the distribution of categorical variables
plt.figure(figsize=(15, 10))

for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 3, i)  # We're expecting 9 categorical columns based on the info
    df_cleaned[col].value_counts(normalize=True).plot(kind='bar')
    plt.title(col)
    plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# The bar plots show the distribution of the categorical variables:
#
# user_conversion_dma shows a variety of locations, with some being more prevalent than others.
# user_use_case_type has a few dominant categories and several less common ones.
# user_account_type seems to have a clear majority category.
# user_attribution_source and user_attribution_channel also show a majority category, with other categories having smaller proportions.
# host_listing_type indicates a few types of listings available.
# is_power_host and is_potential_power_host are boolean values, and their bars represent the proportion of True vs. False in the dataset.
# host_occupancy_type also has a few categories, with one being the most common.

# %%
# Select numerical columns (excluding user_id as it's just an identifier)
numerical_cols_cleaned = df_cleaned.select_dtypes(include=['int64', 'float64']).columns.drop('user_id')

# Plot histograms and boxplots for numerical columns
plt.figure(figsize=(15, 20))

for i, col in enumerate(numerical_cols_cleaned, 1):
    plt.subplot(len(numerical_cols_cleaned), 2, 2*i-1)
    sns.histplot(df_cleaned[col], kde=False)
    plt.title(f'Histogram of {col}')
    
    plt.subplot(len(numerical_cols_cleaned), 2, 2*i)
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# The histograms and boxplots for the numerical columns provide the following insights:
#
# The histograms confirm that many of the numerical variables are skewed, with a concentration of values at the lower end of the scale. This suggests that most users have low counts for reservations, conversations, and listings.
#
# The boxplots show that there are outliers present in many of these variables, evident from the points that lie outside the whiskers of the boxplots. Outliers may be valid values or may indicate data entry errors; the context of the data is important for making this determination.
#
# host_published_listing_count, host_current_published_listing_count, and conversations_as_host_count show a particularly large number of outliers, suggesting that there are a few hosts with significantly more activity than the average.

# %%
# Investigate the 'user_created_timestamp' column
valid_timestamps = df_cleaned['user_created_timestamp'].dropna()

# Get the earliest and latest timestamp
earliest_timestamp = valid_timestamps.min()
latest_timestamp = valid_timestamps.max()

# Check for duplicates
duplicates = df_cleaned.duplicated().sum()

earliest_timestamp, latest_timestamp, duplicates
# Out:
# (Timestamp('2023-11-06 00:00:12'), Timestamp('2023-11-06 23:59:30'), 0)

# %% [markdown]
# The user_created_timestamp column, after removing the NaT (not a timestamp) entries, spans across a single day from November 7, 2023, at 00:00:12 to November 7, 2023, at 23:59:30. This indicates that all the valid timestamps recorded are within one day, which may suggest a data collection or entry issue considering the original data had more non-null timestamps before cleaning.
#
# There are no duplicate rows in the dataset, so no action is needed there.
#
# For the final part of our EDA, let's perform some multivariate analysis. We'll look at the relationships between some of the numerical variables and the categorical variables. Given the skewness in the data, using non-parametric statistics could be helpful, such as the Spearman rank correlation for numerical variables or comparing medians across different groups for categorical variables.

# %% [markdown]
# Great, let's proceed with the multivariate analysis. For numerical variables, we'll use the Spearman rank correlation instead of the Pearson correlation because it can better handle non-normal distributions and outliers. This will give us an idea of whether there are any monotonic relationships between the numerical variables.
#
# For the categorical variables, we'll look at how the numerical variables distribute across different categories. Since we have a lot of skewed distributions, we'll use median values instead of means to compare across groups, as medians are less sensitive to outliers.

# %%
# Calculate the Spearman rank correlation matrix
spearman_corr_matrix = df_cleaned[numerical_cols_cleaned].corr(method='spearman')

# Plot the heatmap for Spearman rank correlation
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Spearman Rank Correlation Matrix')
plt.show()

# %% [markdown]
# The Spearman Rank Correlation Matrix shows the monotonic relationships between the numerical variables:
#
# The correlations are generally similar to those we observed with the Pearson correlation, which is expected because the relationships are likely strong and linear, which Spearman can also capture.
# The high correlations that we previously observed remain high, confirming those relationships.
# Next, we'll examine how the numerical variables distribute across different categories of some key categorical variables. We'll choose a couple of categorical variables that might have interesting interactions with numerical variables. Let's proceed with comparing the median values of numerical variables across different categories.​

# %%
# Select a few categorical variables for comparison
categorical_vars_for_comparison = ['user_account_type', 'is_power_host', 'is_potential_power_host']

# Create boxplots to compare the distributions of numerical variables across the categories
plt.figure(figsize=(15, 5 * len(categorical_vars_for_comparison)))

for i, cat_var in enumerate(categorical_vars_for_comparison, 1):
    for j, num_var in enumerate(numerical_cols_cleaned, 1):
        plt.subplot(len(categorical_vars_for_comparison), len(numerical_cols_cleaned), (i-1)*len(numerical_cols_cleaned)+j)
        sns.boxplot(x=cat_var, y=num_var, data=df_cleaned)
        plt.xticks(rotation=45, ha='right')
        plt.title(f'{num_var} by {cat_var}')

plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots show how the numerical variables are distributed across different categories of selected categorical variables:
#
# For user_account_type, there are noticeable differences in the medians of some numerical variables, such as host_published_listing_count, between different account types. This suggests that the type of user account might be associated with the level of activity on the platform.
#
# is_power_host also shows differences in activity-related variables. Power hosts tend to have higher counts of published listings and conversations as a host, which aligns with what one might expect from more active or experienced hosts.
#
# Similarly, is_potential_power_host shows distinctions in the same variables, indicating that potential power hosts are also more active than the average.
#
# The outliers are quite prominent in these plots, which is consistent with the earlier analysis showing that there are a few users with very high activity levels.
#
# This concludes the multivariate analysis. If you have any more specific analyses in mind or other aspects of the data you would like to explore, please let me know.​

# %% [markdown]
# # The business needs recommendations for their acquistion of renters. how do we define best renters.?

# %% [markdown]
# In the context of a business that operates a platform for rentals, defining the "best renters" would typically be based on a combination of factors that indicate the renter's value to the platform. These can include:
#
# Financial Contribution: Renters who make frequent reservations or those with higher total spending might be considered more valuable.
#
# Reliability: Renters with a high rate of successful reservations (without cancellations or issues) would be seen as reliable.
#
# Longevity: Renters who have been using the platform for a longer time may be more likely to continue doing so, representing a steady stream of income.
#
# Feedback/Reviews: Positive feedback from hosts could also be a factor if the dataset includes such information.
#
# Compliance: Renters who follow platform rules and guidelines, indicated by a lack of reports or issues, would be favorable.
#
# Engagement: Renters who engage more with the platform, whether through reviews, ratings, or other interactions, can provide value beyond just their direct financial contribution.

# %% [markdown]
# From the data we have, we might consider the following as indicators of the "best renters":
#
# <li>High renter_reservation_count and renter_successful_reservation_count: Indicates frequent use of the platform.</li>
# <li>Low or zero delinquent_renter flags: Suggests reliability and compliance.</li>
# <li>Customer service usage (customer_service_usage): This could be a double-edged sword. Renters who use customer service effectively to resolve issues may be positive, but excessive use might also indicate problems.</li>
#
#
# To provide recommendations for the acquisition of such renters, we could analyze the characteristics of the current "best renters" based on the above criteria and identify common attributes or behaviors. This information could then be used to target similar user segments in marketing campaigns or to tailor the platform's features to attract and retain such users.

# %% [markdown]
# Shall we proceed with identifying the "best renters" based on the available data, and then derive insights on how to acquire more users like them?

# %% [markdown]
# To identify the "best renters," we will use the available data to create a profile based on the criteria we discussed. We'll consider the following indicators:
#
# <li>High renter_reservation_count: Indicates frequent use of the platform.</li>
# <li>High renter_successful_reservation_count: Indicates reliability in completing reservations.</li>
# <li>Low or zero delinquent_renter flags: Suggests compliance with payment and platform policies.</li>
# <li>Engagement (conversations_as_renter_count): Indicates active communication, which can be a sign of engagement.</li>
#
# We'll analyze these variables to understand the characteristics of the top renters.
#
# For this analysis, we can define the "best renters" as those who are in the top percentile (for example, the 90th percentile) for both renter_reservation_count and renter_successful_reservation_count, and have no delinquent_renter flags.
#
# Let's calculate the 90th percentile for renter_reservation_count and renter_successful_reservation_count, and identify the renters who meet these criteria. We'll then look at their profiles to see if we can find any common attributes or behaviors.

# %%
# Define the 90th percentile for renter_reservation_count and renter_successful_reservation_count
percentile_90_reservation_count = df_cleaned['renter_reservation_count'].quantile(0.9)
percentile_90_successful_reservation_count = df_cleaned['renter_successful_reservation_count'].quantile(0.9)

# Identify "best renters" based on the defined criteria
best_renters = df_cleaned[
    (df_cleaned['renter_reservation_count'] >= percentile_90_reservation_count) &
    (df_cleaned['renter_successful_reservation_count'] >= percentile_90_successful_reservation_count) &
    (df_cleaned['delinquent_renter'] == 0)
]

# Now, let's summarize the best renters to understand their profiles
best_renters_profile = best_renters.describe(include='all', datetime_is_numeric=True)
best_renters_profile_transposed = best_renters_profile.transpose()

# Display a transposed summary for better readability
best_renters_profile_transposed
# Out:
#                                        count unique             top  freq  \
# user_id                               1159.0    NaN             NaN   NaN
# user_created_timestamp                   428    NaN             NaN   NaN
# user_conversion_dma                     1159    129     Los Angeles   125
# user_use_case_type                      1159      3          renter  1138
# user_account_type                       1159      2     residential  1158
# user_attribution_source                 1159      5            Paid   647
# user_attribution_channel                 668     17          Google   548
# host_published_listing_count          1159.0    NaN             NaN   NaN
# host_current_published_listing_count    22.0    NaN             NaN   NaN
# host_average_listing_quality_score      22.0    NaN             NaN   NaN
# host_listing_type                       1159      2            Both  1152
# is_power_host                           1159      1           False  1159
# ...

# %% [markdown]
# Here's a profile of the "best renters" based on our criteria:
#
# User ID: A wide range of user IDs, indicating a mix of newer and older accounts.
# User Created Timestamp: Dates are all on November 7, 2023, which matches the range of the entire dataset.
# User Conversion DMA: The most common location is Los Angeles, suggesting a potential geographic target for marketing.
# User Use Case Type: The majority of the best renters have 'renter' as their use case type.
# User Account Type: Nearly all best renters have 'residential' as their account type.
# User Attribution Source: The 'Paid' attribution source is the most common, which might indicate that paid marketing is effective in acquiring valuable renters.
# User Attribution Channel: 'Google' is the most common channel, suggesting that focusing on this channel could be beneficial.
# Host Published Listing Count: Low counts, with a maximum of 23, which suggests that these users are more renter-focused.
# Host Current Published Listing Count & Quality Score: Data is mostly missing or not applicable to renters.
# Host Listing Type: Almost all best renters have 'Both' as their listing type, though this may need further clarification.
# Is Power Host & Is Potential Power Host: Almost none of the best renters are power hosts or potential power hosts, which aligns with them being primarily renters.
# Host Occupancy Type: Not applicable to most renters.
# Renter Reservation Count & Successful Reservation Count: High counts, as expected from the selection criteria.
# Conversations as Renter Count: There's a range, with some renters having many conversations, which could indicate engagement.
# Delinquent Renter: None of the best renters are marked as delinquent, indicating good standing.
# Customer Service Usage: Some use of customer service, but not excessively high, indicating that while they may have occasional issues, they are not problematic users.

# %% [markdown]
# From these insights, the business can consider the following recommendations to acquire more of the best renters:
#
# Geographic Focus: Target marketing efforts in areas where the best renters are most common, such as Los Angeles.
# Paid Marketing: Continue or increase investment in paid marketing channels, especially via Google, which seems to bring in valuable renters.
# Renter-Centric Features: Develop and highlight platform features that cater to the needs of renters, as they are the most active and reliable users.
# Customer Service: Ensure customer service is efficient and effective, as the best renters do use these services but not to an excessive degree.
# Engagement Programs: Encourage active communication and engagement, possibly through incentives for reviews or other interactions.

# %% [markdown]
# The business needs recommendations for their acquistion of hosts. how would you define the best hosts\

# %% [markdown]
# Identifying the "best hosts" on a rental platform involves assessing factors that contribute not only to the platform's revenue but also to its reputation and user satisfaction. Here are some criteria that could be considered when defining the best hosts:
#
# Listing Quality: High-quality listings with good descriptions, clear and attractive photos, and all necessary amenities.
#
# Reliability: Hosts who consistently honor reservations without cancellations.
#
# Ratings and Reviews: Positive feedback from renters, high ratings, and testimonials.
#
# Activity Level: Regularly updated listings and prompt responses to renter inquiries.
#
# Occupancy Rate: A higher occupancy rate may indicate that the host is in-demand and manages their listings well.
#
# Compliance: Adherence to platform policies and local regulations.
#
# Experience: Experienced hosts might be more skilled at managing their listings and providing a better experience for renters.

# %% [markdown]
# Using the dataset we have, we could consider the following as indicators of the "best hosts":
#
# High host_published_listing_count: Suggests an active and experienced host.
# High host_current_published_listing_count: Indicates that the host has many listings available.
# High host_average_listing_quality_score: Could indicate the quality of the host's listings.
# Low number of conversations_as_host_count relative to the number of reservations: This might suggest efficiency in converting inquiries to reservations.
# is_power_host: Being a power host may imply a higher level of service and experience.
# host_occupancy_type: Certain types of occupancy may be more desirable depending on the platform's focus (e.g., short-term vs. long-term rentals).
#
# To provide recommendations for acquiring such hosts, we could analyze the characteristics of current "best hosts" based on the above criteria and identify common attributes. This information can then be used to target similar profiles in outreach campaigns or to tailor features and incentives on the platform to attract and retain such hosts.
#
# Would you like to proceed with identifying the "best hosts" based on the available data, and then derive insights on how to acquire more users like them?

# %% [markdown]
# To identify the "best hosts" using the dataset, we'll follow a similar approach as we did with the renters. We'll establish criteria based on the available data, focusing on indicators of success and quality for hosts. We'll then analyze these variables to find common characteristics among the top performers.
#
# The criteria might include:
#
# High host_published_listing_count: Suggests active engagement with the platform.
# High host_current_published_listing_count: Indicates availability and possibly variety in offerings.
# High host_average_listing_quality_score: Reflects the quality of listings presented.
# Status as is_power_host: Implies a higher level of service and experience.
# Efficiency in conversation-to-reservation ratio: Fewer conversations needed per reservation could indicate effective communication and a high conversion rate.
#
# For this analysis, we can define the "best hosts" as those who are in the top percentile (for example, the 90th percentile) for host_published_listing_count and host_current_published_listing_count, have a high host_average_listing_quality_score (e.g., above the median), and are identified as is_power_host.

# %%
# Define the 90th percentile for host_published_listing_count and host_current_published_listing_count
percentile_90_published_listing_count = df_cleaned['host_published_listing_count'].quantile(0.9)
percentile_90_current_published_listing_count = df_cleaned['host_current_published_listing_count'].quantile(0.9)

# Median for host_average_listing_quality_score
median_listing_quality_score = df_cleaned['host_average_listing_quality_score'].median()

# Identify "best hosts" based on the defined criteria
best_hosts = df_cleaned[
    (df_cleaned['host_published_listing_count'] >= percentile_90_published_listing_count) &
    (df_cleaned['host_current_published_listing_count'] >= percentile_90_current_published_listing_count) &
    (df_cleaned['host_average_listing_quality_score'] >= median_listing_quality_score) &
    (df_cleaned['is_power_host'] == True)
]

# Now, let's summarize the best hosts to understand their profiles
best_hosts_profile = best_hosts.describe(include='all', datetime_is_numeric=True)
best_hosts_profile_transposed = best_hosts_profile.transpose()

# Display a transposed summary for better readability
best_hosts_profile_transposed
# Out:
#                                      count unique                    top freq  \
# user_id                                9.0    NaN                    NaN  NaN
# user_created_timestamp                   5    NaN                    NaN  NaN
# user_conversion_dma                      9      8  Miami-Fort Lauderdale    2
# user_use_case_type                       9      1                   host    9
# user_account_type                        9      2            residential    8
# user_attribution_source                  9      3                   Paid    5
# user_attribution_channel                 5      4                 Google    2
# host_published_listing_count           9.0    NaN                    NaN  NaN
# host_current_published_listing_count   9.0    NaN                    NaN  NaN
# host_average_listing_quality_score     9.0    NaN                    NaN  NaN
# host_listing_type                        9      2     Vehicle Accessible    5
# ...

# %% [markdown]
# Based on our criteria, the profile of the "best hosts" includes the following attributes:
#
# Host Count: There are 9 hosts who meet the criteria of being in the top 90th percentile for both published and current listing counts, have a high average listing quality score, and are power hosts.
# User Account Types: Most are residential accounts, with one being a commercial account.
# User Attribution Source: The majority were acquired through paid sources, highlighting the importance of paid marketing in attracting top hosts.
# User Attribution Channel: Google is a common channel, but there are a few others represented, suggesting a diversified channel strategy could be beneficial.
# Host Published Listing Count: Ranges from 15 to 105, with a median of 31, indicating these hosts have a significant presence on the platform.
# Host Current Published Listing Count: Ranges from 11 to 104, with a median of 22, confirming these hosts have multiple active listings.
# Host Average Listing Quality Score: Scores are high, ranging from 77.92 to 90.57, suggesting that high-quality listings are a feature of top hosts.
# Host Listing Type: 'Vehicle Accessible' and another unspecified type are the listing types, which could suggest a feature that's valued or prominent in the top listings.
# Is Potential Power Host: Most of the best hosts are also potential power hosts, which might indicate a trajectory towards becoming even more influential on the platform.
# Host Occupancy Type: All are marked as 'partially occupied', which might suggest a balance between personal use and rental availability.
# Conversations as Host Count: There is a wide range, suggesting varying degrees of engagement with potential renters.
# From these insights, the business can consider the following recommendations to acquire more of the best hosts:
#
# Paid Marketing: Continue or increase investment in paid marketing, particularly through channels that have proven effective like Google.
# Residential Focus: Focus on acquiring residential hosts, as they represent the majority of top hosts.
# Quality Incentives: Encourage high-quality listings with incentives or features that highlight the importance of quality scores.
# Diversified Occupancy: Consider promoting a model that balances personal use with rental availability, as seen in the 'partially occupied' category.
# Engagement Encouragement: Develop tools and services that help hosts manage multiple listings and engage effectively with potential renters.
# With these recommendations, the platform can tailor its host acquisition strategies to target users who are more likely to become top hosts, thereby increasing the overall quality and reliability of listings available to renters.

# %% [markdown]
# # What strategy would you give them to acquire the best hosts

# %% [markdown]
# Based on the profile of the "best hosts" that we've identified from the data, here are some strategic recommendations the business could consider to attract and retain top-performing hosts:
#
# Targeted Marketing Campaigns:
#
# Use data-driven insights to target potential hosts in specific DMAs where top hosts are currently active, especially if these areas have characteristics that are likely to produce similar high-quality hosts.
# Tailor advertising to emphasize the benefits and support that the platform provides to hosts to maintain high-quality listings.
# Enhanced Listing Support:
#
# Provide tools and resources to help new hosts create high-quality listings, such as photography services, writing assistance for descriptions, and checklists for amenities.
# Offer workshops or webinars on best practices for hosting, highlighting successful hosts as case studies.
#
# Financial Incentives:
# Implement a tiered rewards system where hosts can earn benefits or bonuses for reaching certain milestones, such as a number of successful bookings or maintaining high-quality scores.
# Consider offering promotional rates or reduced fees for new hosts to encourage them to list more properties.
# Community Building:
#
# Foster a community of hosts through forums, local meetups, and conferences to encourage sharing of tips and strategies.
# Establish a mentorship program where experienced hosts can guide new hosts, leveraging the expertise of power hosts.
#
# Platform Features and Policies:
# Develop and highlight platform features that simplify the management of multiple listings, as top hosts tend to have several listings.
# Ensure the platform has clear and host-friendly policies that protect hosts and their properties while also ensuring a high-quality experience for renters.
#
# Feedback and Quality Improvement:
# Regularly gather feedback from hosts to improve the platform and address common issues.
# Continuously monitor and reward high-quality listings and host performance with public recognition and additional visibility on the platform.
#
# Data Analytics:
# Invest in data analytics to better understand the drivers of host satisfaction and success, and to personalize the support and resources provided to hosts based on their needs and performance.
#
# Strategic Partnerships:
# Partner with real estate agencies, home furnishing companies, or cleaning services to provide hosts with discounts or services that add value to their hosting experience.
# By implementing these strategies, the platform can attract hosts who are likely to provide high-quality, reliable, and in-demand rental experiences, leading to better outcomes for both hosts and renters.
#
# The specific strategies should be tailored to the platform's capabilities, market conditions, and the needs and preferences of potential high-quality hosts.

# %% [markdown]
# # What strategy would you give them to acquire the best Renters

# %% [markdown]
# To acquire the best renters, the strategies should be designed to appeal to individuals who are likely to become frequent, reliable, and engaged users of the platform. Here's a tailored strategy based on the profile of the "best renters" as previously identified:
#
# Personalized Marketing Campaigns:
#
# Use data analysis to identify the demographics and behaviors of the best renters and target similar segments with personalized ads.
# Focus on regions or cities where the best renters are most prevalent, as identified by the user_conversion_dma data.
#
# Incentive Programs:
# Develop a loyalty program that rewards frequent renters with discounts, early access to premium listings, or other perks.
# Offer referral bonuses to current users who refer new renters that meet the criteria of best renters after a certain number of successful stays.
# Seamless User Experience:
#
# Ensure the booking process is simple and user-friendly, with features such as instant booking for trusted renters.
# Offer a guarantee or insurance to protect renters against cancellations and other potential issues, increasing their confidence in using the platform.
#
# Quality Assurance:
# Maintain high-quality listings to attract renters who are looking for reliable and well-reviewed accommodations.
# Implement a robust review system that highlights the experiences of similar best renters.
#
# Community Engagement:
# Encourage community building through forums, shared experiences, and reviews, fostering a sense of belonging and trust in the platform.
# Organize or sponsor events and meetups for users to enhance brand loyalty and community feeling.
# Responsive Customer Service:
#
# Offer excellent customer support to address any issues renters may face promptly, increasing trust and satisfaction.
# Use feedback from customer service interactions to improve the platform and the services offered.
# Partnerships and Collaborations:
#
# Partner with travel agencies, event organizers, and companies in the hospitality industry to reach potential renters.
# Collaborate with brands that align with the interests of the target renter segments to offer bundled deals or promotions.
# Content Marketing:
#
# Create and share content that is relevant to potential best renters, such as travel tips, destination guides, and hosting stories.
# Use social media influencers and content creators to showcase the benefits of the platform and reach a wider audience.
# Mobile Optimization:
#
# Since many users book through mobile devices, ensure the platform's mobile experience is exceptional, with an easy-to-use app and mobile-responsive design.
# By focusing on these strategies, the platform can attract and retain renters who will contribute positively to the platform's growth and reputation. It's important to regularly analyze renter data to refine these strategies and ensure they align with the evolving preferences and behaviors of the target user base.
