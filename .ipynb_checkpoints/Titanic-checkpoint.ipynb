# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from scipy.stats import norm
import seaborn as sns

# %%
train_df = pd.read_csv("/Users/ashutoshfolane/Documents/VIBHUTI/Git_Repos/Datasets/Titanic_Data/train.csv")
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Groupby Gender

# %%
df_groupby_Sex = train_df.groupby('Sex')
df_groupby_Sex

# %%
df_groupby_Sex.ngroups
# Out:
# 2

# %%
df_groupby_Sex.size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df_groupby_Sex.first()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female            2         1       1
# male              1         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# male                              Braund, Mr. Owen Harris  22.0      1      0
#
#            Ticket     Fare Cabin Embarked
# Sex
# female   PC 17599  71.2833   C85        C
# male    A/5 21171   7.2500   E46        S

# %%
df_groupby_Sex.last()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female          889         0       3
# male            891         0       3
#
#                                             Name   Age  SibSp  Parch  \
# Sex
# female  Johnston, Miss. Catherine Helen "Carrie"  19.0      1      2
# male                         Dooley, Mr. Patrick  32.0      0      0
#
#             Ticket   Fare Cabin Embarked
# Sex
# female  W./C. 6607  23.45   B42        S
# male        370376   7.75  C148        Q

# %%
df_female = df_groupby_Sex.get_group('female')
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
train_df.groupby('Sex').Age.max()
# Out:
# Sex
# female    63.0
# male      80.0
# Name: Age, dtype: float64

# %%
train_df.groupby('Sex').Age.agg(['min','max','median','count','median'])
# Out:
#          min   max  median  count  median
# Sex
# female  0.75  63.0    27.0    261    27.0
# male    0.42  80.0    29.0    453    29.0

# %%
train_df.groupby('Sex').Age.agg(sex_max =('max'), sex_min=('min'))
# Out:
#         sex_max  sex_min
# Sex
# female     63.0     0.75
# male       80.0     0.42

# %%
def categorize(x):
    m = x.mean()
    if m> 29:
        return True
    else:
        return False

# %%
train_df.groupby('Sex').Age.agg(['min','max',categorize])
# Out:
#          min   max  categorize
# Sex
# female  0.75  63.0       False
# male    0.42  80.0        True

# %%
train_df.groupby('Sex').Age.agg(['min','max',lambda x: True if x.mean()> 29 else False])
# Out:
#          min   max  <lambda_0>
# Sex
# female  0.75  63.0       False
# male    0.42  80.0        True

# %%
train_df.groupby('Cabin').size()
# Out:
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Length: 147, dtype: int64

# %%
train_df.groupby('Cabin').filter(lambda x: len(x) >=4)
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 27            28         0       1
# 88            89         1       1
# 205          206         0       3
# 251          252         0       3
# 341          342         1       1
# 390          391         1       1
# 394          395         1       3
# 435          436         1       1
# 438          439         0       1
# 763          764         1       1
# 802          803         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# ...

# %%
# Creating a subset
df_subset = train_df.loc[:, ['Sex', 'Pclass', 'Age', 'Fare']]
df_subset
# Out:
#         Sex  Pclass   Age     Fare
# 0      male       3  22.0   7.2500
# 1    female       1  38.0  71.2833
# 2    female       3  26.0   7.9250
# 3    female       1  35.0  53.1000
# 4      male       3  35.0   8.0500
# ..      ...     ...   ...      ...
# 886    male       2  27.0  13.0000
# 887  female       1  19.0  30.0000
# 888  female       3   NaN  23.4500
# 889    male       1  26.0  30.0000
# 890    male       3  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
# Out:
#       Sex  Pclass        Age        Fare
# 0  female       1  34.611765  106.125798
# 1  female       2  28.722973   21.970121
# 2  female       3  21.750000   16.118810
# 3    male       1  41.281386   67.226127
# 4    male       2  30.740707   19.741782
# 5    male       3  26.507589   12.661633

# %%
df_subset.groupby(['Sex', 'Pclass'], as_index = False).mean()
# Out:
#       Sex  Pclass        Age        Fare
# 0  female       1  34.611765  106.125798
# 1  female       2  28.722973   21.970121
# 2  female       3  21.750000   16.118810
# 3    male       1  41.281386   67.226127
# 4    male       2  30.740707   19.741782
# 5    male       3  26.507589   12.661633

# %%
df_subset.isna().sum()
# Out:
# Sex         0
# Pclass      0
# Age       177
# Fare        0
# dtype: int64
